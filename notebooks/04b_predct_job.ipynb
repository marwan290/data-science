# %%
DF_PATH       = "../data/processed/2_cleaned_data.pkl"
FEATURES_PATH = "../data/processed/features_skills_clusters_counts.pkl"

ROLE_COLS      = ['DevType']
TECH_COLS      = ['LanguageWorkedWith',    'DatabaseWorkedWith',    'WebframeWorkedWith',    'MiscTechWorkedWith']

EXPORT_PATH = '../models/00_model_baseline.pkl'

# %%
# Load packages
import pandas as pd 
import numpy as np
import pickle
import logging
import random
import plotly
import os

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler, minmax_scale, RobustScaler
from sklearn.pipeline import make_pipeline, FeatureUnion
from sklearn.feature_selection import VarianceThreshold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import auc, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

from sklearn.decomposition import PCA, KernelPCA

from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from matplotlib import pyplot as plt

# %%
df = pd.read_pickle(DF_PATH)
df = df.drop("skills_clusters",axis=1).copy()
# Out:
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
df['DevType'].columns
# Out:
# Index(['Academic researcher', 'Data or business analyst',
#        'Data scientist or machine learning specialist',
#        'Database administrator', 'DevOps specialist', 'Developer, QA or test',
#        'Developer, back-end', 'Developer, desktop or enterprise applications',
#        'Developer, embedded applications or devices', 'Developer, front-end',
#        'Developer, full-stack', 'Developer, game or graphics',
#        'Developer, mobile', 'Engineer, data', 'Scientist',
#        'System administrator'],
#       dtype='object')

# %%
def generate_columns_data(role_name):
    '''Generate balance data for singel job'''
    
    role_mask = (df['DevType'][role_name]==1)
    
    role = df[role_mask].index.to_series()
    another_role = df[~role_mask].index.to_series()
    print(len(role))
    sample_size = len(role)
    if len(another_role) > sample_size:
#         print(len(another_role))
        another_role = another_role.sample(sample_size).copy()
#         print(len(another_role))
    
    all_index = role.tolist() + another_role.tolist()
    role_df = df.loc[all_index].copy()
    bin_role = role_df['DevType'][role_name]
    skills = role_df.drop('DevType', axis=1).droplevel(0, axis=1).copy()
    return skills,bin_role

# %%
model_df = generate_rcolumns_data('Data or business analyst')
# Out:
# 669
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
model_df[1].value_counts()
# Out:
# 1    669
# 0    669
# Name: Data or business analyst, dtype: int64

# %%
roles
# Out:
# ['Academic researcher',
#  'Data or business analyst',
#  'Data scientist or machine learning specialist',
#  'Database administrator',
#  'DevOps specialist',
#  'Developer, QA or test',
#  'Developer, back-end',
#  'Developer, desktop or enterprise applications',
#  'Developer, embedded applications or devices',
#  'Developer, front-end',
#  'Developer, full-stack',
#  'Developer, game or graphics',
#  'Developer, mobile',
#  'Engineer, data',
#  'Scientist',
#  'System administrator']

# %%
roles = df['DevType'].columns.tolist()

# %%
models = {}

for role in roles:
    
    skills,bin_role = generate_columns_data(role)
    X_train, X_test, y_train, y_test = train_test_split(skills, bin_role, random_state=0)
    
    role_clf = tree.DecisionTreeClassifier()
    role_clf.fit(X_train, y_train)
    
    score_train = precision_score(y_train, role_clf.predict(X_train))
    score_test = precision_score(y_test, role_clf.predict(X_test))
    
    models[role] = {'clf': role_clf, 'scores': [score_train, score_test]}
# Out:
# 581
# 669
# 799
# 296
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 677
# 493
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 5503
# 1671
# 795
# 2890
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 5578
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 342
# 1859
# 483
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 292
# 440
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
pd.DataFrame(models).T
# Out:
#                                                                     clf  \
# Academic researcher                            DecisionTreeClassifier()
# Data or business analyst                       DecisionTreeClassifier()
# Data scientist or machine learning specialist  DecisionTreeClassifier()
# Database administrator                         DecisionTreeClassifier()
# DevOps specialist                              DecisionTreeClassifier()
# Developer, QA or test                          DecisionTreeClassifier()
# Developer, back-end                            DecisionTreeClassifier()
# Developer, desktop or enterprise applications  DecisionTreeClassifier()
# Developer, embedded applications or devices    DecisionTreeClassifier()
# Developer, front-end                           DecisionTreeClassifier()
# Developer, full-stack                          DecisionTreeClassifier()
# Developer, game or graphics                    DecisionTreeClassifier()
# Developer, mobile                              DecisionTreeClassifier()
# Engineer, data                                 DecisionTreeClassifier()
# Scientist                                      DecisionTreeClassifier()
# System administrator                           DecisionTreeClassifier()
#
#                                                                                  scores
# Academic researcher                            [0.9887387387387387, 0.6482758620689655]
# Data or business analyst                                      [1.0, 0.7468354430379747]
# Data scientist or machine learning specialist                 [1.0, 0.8241206030150754]
# Database administrator                         [0.9955156950672646, 0.6363636363636364]
# DevOps specialist                                             [1.0, 0.6705202312138728]
# Developer, QA or test                                         [1.0, 0.5677966101694916]
# Developer, back-end                            [0.9888998519980267, 0.6570370370370371]
# Developer, desktop or enterprise applications  [0.9855653568564555, 0.6255924170616114]
# Developer, embedded applications or devices    [0.9931740614334471, 0.7696078431372549]
# Developer, front-end                             [0.99074502545118, 0.7366255144032922]
# Developer, full-stack                          [0.9881125667151868, 0.6386247256766642]
# Developer, game or graphics                                 [0.996, 0.7419354838709677]
# Developer, mobile                              [0.9978417266187051, 0.8126315789473684]
# Engineer, data                                                [1.0, 0.6694214876033058]
# Scientist                                      [0.9955357142857143, 0.6231884057971014]
# System administrator                           [0.9969418960244648, 0.6752136752136753]

# %%
for role in roles:
    
    skills,bin_role = generate_columns_data(role)
    X_train, X_test, y_train, y_test = train_test_split(skills, bin_role, random_state=0)
    X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train, random_state=0)
    
    hpt = []
    for depth in range(1,20):
        role_clf = tree.DecisionTreeClassifier(max_depth=depth)
        role_clf.fit(X_train, y_train)

        score_train = f1_score(y_train, role_clf.predict(X_train))
        score_validate = f1_score(y_validate, role_clf.predict(X_validate))

        hpt.append([depth,score_train,score_validate])
    
    hpt = pd.DataFrame(hpt, columns=['depth', 'score_train', 'score_validate']).set_index('depth')
    
    hpt.plot(title = role)
    plt.show()
# Out:
# 581
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 669
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 799
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 296
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 677
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 493
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 5503
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 1671
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 795
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 2890
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 5578
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 342
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 1859
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 483
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 292
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# 440
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
models = {}

for role in roles:
    
    skills,bin_role = generate_columns_data(role)
    X_train, X_test, y_train, y_test = train_test_split(skills, bin_role, random_state=0)
    X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train, random_state=0)
    
    best_model = None
    best_validate = -np.inf
    for depth in range(1,20):
        role_clf = tree.DecisionTreeClassifier(max_depth=depth)
        role_clf.fit(X_train, y_train)

        score_train = f1_score(y_train, role_clf.predict(X_train))
        score_validate = f1_score(y_validate, role_clf.predict(X_validate))
        if score_validate > best_validate:
            best_validate = score_validate
            best_model = role_clf

    score_train = f1_score(y_train, role_clf.predict(X_train))
    score_validate = f1_score(y_validate, role_clf.predict(X_validate))
    score_test = f1_score(y_test, role_clf.predict(X_test))
    models[role] = {'model': best_model,
                   'data': {'X':skills, 'y': bin_role},
                   'score': {'test': score_test, 
                             'train': score_train, 
                             'validate': score_validate}
        
    }           
    
    
    print("**********************")
    print(role)
    print(tree.export_text(best_model,feature_names=X_train.columns.tolist()))
    print('-------------------------------')
# Out:
# 581
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Academic researcher
# |--- Python <= 0.50
# |   |--- C <= 0.50
# |   |   |--- R <= 0.50
# |   |   |   |--- C++ <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- C++ >  0.50
# |   |   |   |   |--- class: 1
# |   |   |--- R >  0.50
# |   |   |   |--- Node.js <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- Node.js >  0.50
# |   |   |   |   |--- class: 0
# |   |--- C >  0.50
# |   |   |--- SQLite <= 0.50
# |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- Oracle >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- SQLite >  0.50
# |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |--- class: 1
# |--- Python >  0.50
# |   |--- R <= 0.50
# |   |   |--- C++ <= 0.50
# |   |   |   |--- Redis <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- Redis >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- C++ >  0.50
# |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |--- class: 0
# |   |--- R >  0.50
# |   |   |--- .NET Core <= 0.50
# |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- Oracle >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- .NET Core >  0.50
# |   |   |   |--- class: 0
#
# -------------------------------
# 669
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Data or business analyst
# |--- Pandas <= 0.50
# |   |--- SQL <= 0.50
# |   |   |--- VBA <= 0.50
# |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |--- MariaDB <= 0.50
# |   |   |   |   |   |--- IBM DB2 <= 0.50
# |   |   |   |   |   |   |--- Keras <= 0.50
# |   |   |   |   |   |   |   |--- R <= 0.50
# |   |   |   |   |   |   |   |   |--- Microsoft SQL Server <= 0.50
# |   |   |   |   |   |   |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Dart <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Dart >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Microsoft SQL Server >  0.50
# |   |   |   |   |   |   |   |   |   |--- .NET <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- MySQL >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- .NET >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- R >  0.50
# |   |   |   |   |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |   |   |   |   |--- C <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- C >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Keras >  0.50
# |   |   |   |   |   |   |   |--- Java <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Java >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- IBM DB2 >  0.50
# |   |   |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- MariaDB >  0.50
# |   |   |   |   |   |--- PHP <= 0.50
# |   |   |   |   |   |   |--- Ansible <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Ansible >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PHP >  0.50
# |   |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Oracle >  0.50
# |   |   |   |   |--- C# <= 0.50
# |   |   |   |   |   |--- Angular <= 0.50
# |   |   |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |   |   |--- Teraform <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Teraform >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Angular >  0.50
# |   |   |   |   |   |   |--- C++ <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- C++ >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- C# >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- VBA >  0.50
# |   |   |   |--- ASP.NET <= 0.50
# |   |   |   |   |--- Assembly <= 0.50
# |   |   |   |   |   |--- R <= 0.50
# |   |   |   |   |   |   |--- .NET <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- .NET >  0.50
# |   |   |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- R >  0.50
# |   |   |   |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- MySQL >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Assembly >  0.50
# |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- ASP.NET >  0.50
# |   |   |   |   |--- class: 0
# |   |--- SQL >  0.50
# |   |   |--- R <= 0.50
# |   |   |   |--- Node.js <= 0.50
# |   |   |   |   |--- VBA <= 0.50
# |   |   |   |   |   |--- Spring <= 0.50
# |   |   |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |   |   |--- Microsoft SQL Server <= 0.50
# |   |   |   |   |   |   |   |   |--- Java <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Ruby <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- C <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- C >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Ruby >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Java >  0.50
# |   |   |   |   |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Laravel <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Laravel >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Microsoft SQL Server >  0.50
# |   |   |   |   |   |   |   |   |--- ASP.NET Core <= 0.50
# |   |   |   |   |   |   |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Xamarin <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Xamarin >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Java <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Java >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ASP.NET Core >  0.50
# |   |   |   |   |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |   |   |--- Redis <= 0.50
# |   |   |   |   |   |   |   |   |--- Elasticsearch <= 0.50
# |   |   |   |   |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Elasticsearch >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Redis >  0.50
# |   |   |   |   |   |   |   |   |--- Cassandra <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Vue.js <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Vue.js >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Cassandra >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Spring >  0.50
# |   |   |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- VBA >  0.50
# |   |   |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |   |   |--- PHP <= 0.50
# |   |   |   |   |   |   |   |--- Redis <= 0.50
# |   |   |   |   |   |   |   |   |--- C# <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- C# >  0.50
# |   |   |   |   |   |   |   |   |   |--- jQuery <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- jQuery >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Redis >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PHP >  0.50
# |   |   |   |   |   |   |   |--- Java <= 0.50
# |   |   |   |   |   |   |   |   |--- Ruby on Rails <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Ruby on Rails >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Java >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Node.js >  0.50
# |   |   |   |   |--- Ruby <= 0.50
# |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |--- React Native <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- React Native >  0.50
# |   |   |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |--- Vue.js <= 0.50
# |   |   |   |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Vue.js >  0.50
# |   |   |   |   |   |   |   |--- Express <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Express >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Ruby >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- R >  0.50
# |   |   |   |--- Hadoop <= 0.50
# |   |   |   |   |--- Elasticsearch <= 0.50
# |   |   |   |   |   |--- Apache Spark <= 0.50
# |   |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |   |   |   |--- MariaDB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- .NET <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- .NET >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- MariaDB >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Apache Spark >  0.50
# |   |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |   |--- Java <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Java >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Elasticsearch >  0.50
# |   |   |   |   |   |--- Flask <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Flask >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Hadoop >  0.50
# |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |--- class: 1
# |--- Pandas >  0.50
# |   |--- Spring <= 0.50
# |   |   |--- C++ <= 0.50
# |   |   |   |--- Go <= 0.50
# |   |   |   |   |--- Flutter <= 0.50
# |   |   |   |   |   |--- Teraform <= 0.50
# |   |   |   |   |   |   |--- Express <= 0.50
# |   |   |   |   |   |   |   |--- SQL <= 0.50
# |   |   |   |   |   |   |   |   |--- Apache Spark <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Rust <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Kotlin <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Kotlin >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Rust >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Apache Spark >  0.50
# |   |   |   |   |   |   |   |   |   |--- Hadoop <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Hadoop >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- SQL >  0.50
# |   |   |   |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |   |   |   |--- DynamoDB <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Keras <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Keras >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- DynamoDB >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- jQuery <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- jQuery >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- C# <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- C# >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- R <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- R >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Express >  0.50
# |   |   |   |   |   |   |   |--- Django <= 0.50
# |   |   |   |   |   |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Django >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Teraform >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Flutter >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Go >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- C++ >  0.50
# |   |   |   |--- TensorFlow <= 0.50
# |   |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |   |--- jQuery <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- jQuery >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- MySQL >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- TensorFlow >  0.50
# |   |   |   |   |--- class: 0
# |   |--- Spring >  0.50
# |   |   |--- Microsoft SQL Server <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- Microsoft SQL Server >  0.50
# |   |   |   |--- class: 1
#
# -------------------------------
# 799
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Data scientist or machine learning specialist
# |--- Pandas <= 0.50
# |   |--- R <= 0.50
# |   |   |--- TensorFlow <= 0.50
# |   |   |   |--- Python <= 0.50
# |   |   |   |   |--- C++ <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- C++ >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Python >  0.50
# |   |   |   |   |--- Torch/PyTorch <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Torch/PyTorch >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- TensorFlow >  0.50
# |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |--- C <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- C >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |--- Kotlin <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Kotlin >  0.50
# |   |   |   |   |   |--- class: 0
# |   |--- R >  0.50
# |   |   |--- Ruby <= 0.50
# |   |   |   |--- Gatsby <= 0.50
# |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Gatsby >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- Ruby >  0.50
# |   |   |   |--- class: 0
# |--- Pandas >  0.50
# |   |--- jQuery <= 0.50
# |   |   |--- Couchbase <= 0.50
# |   |   |   |--- Unreal Engine <= 0.50
# |   |   |   |   |--- TensorFlow <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- TensorFlow >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Unreal Engine >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- Couchbase >  0.50
# |   |   |   |--- class: 0
# |   |--- jQuery >  0.50
# |   |   |--- Django <= 0.50
# |   |   |   |--- Cassandra <= 0.50
# |   |   |   |   |--- Swift <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Swift >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Cassandra >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- Django >  0.50
# |   |   |   |--- Flask <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Flask >  0.50
# |   |   |   |   |--- Angular <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Angular >  0.50
# |   |   |   |   |   |--- class: 0
#
# -------------------------------
# 296
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Database administrator
# |--- SQL <= 0.50
# |   |--- class: 0
# |--- SQL >  0.50
# |   |--- class: 1
#
# -------------------------------
# 677
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# DevOps specialist
# |--- Teraform <= 0.50
# |   |--- Ansible <= 0.50
# |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |--- class: 1
# |   |--- Ansible >  0.50
# |   |   |--- Angular.js <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- Angular.js >  0.50
# |   |   |   |--- class: 0
# |--- Teraform >  0.50
# |   |--- Dart <= 0.50
# |   |   |--- Gatsby <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- Gatsby >  0.50
# |   |   |   |--- class: 0
# |   |--- Dart >  0.50
# |   |   |--- class: 0
#
# -------------------------------
# 493
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Developer, QA or test
# |--- Java <= 0.50
# |   |--- TypeScript <= 0.50
# |   |   |--- Express <= 0.50
# |   |   |   |--- SQL <= 0.50
# |   |   |   |   |--- Keras <= 0.50
# |   |   |   |   |   |--- ASP.NET Core <= 0.50
# |   |   |   |   |   |   |--- C# <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- C# >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- ASP.NET Core >  0.50
# |   |   |   |   |   |   |--- Microsoft SQL Server <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Microsoft SQL Server >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Keras >  0.50
# |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- SQL >  0.50
# |   |   |   |   |--- VBA <= 0.50
# |   |   |   |   |   |--- MariaDB <= 0.50
# |   |   |   |   |   |   |--- ASP.NET <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- ASP.NET >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- MariaDB >  0.50
# |   |   |   |   |   |   |--- Unity 3D <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Unity 3D >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- VBA >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- Express >  0.50
# |   |   |   |--- DynamoDB <= 0.50
# |   |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |--- C <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- C >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- DynamoDB >  0.50
# |   |   |   |   |--- class: 1
# |   |--- TypeScript >  0.50
# |   |   |--- Python <= 0.50
# |   |   |   |--- C <= 0.50
# |   |   |   |   |--- Unity 3D <= 0.50
# |   |   |   |   |   |--- Go <= 0.50
# |   |   |   |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Go >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Unity 3D >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- C >  0.50
# |   |   |   |   |--- class: 1
# |   |   |--- Python >  0.50
# |   |   |   |--- Vue.js <= 0.50
# |   |   |   |   |--- Keras <= 0.50
# |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |--- Node.js <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Node.js >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Keras >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Vue.js >  0.50
# |   |   |   |   |--- class: 0
# |--- Java >  0.50
# |   |--- Spring <= 0.50
# |   |   |--- DynamoDB <= 0.50
# |   |   |   |--- Kotlin <= 0.50
# |   |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |   |--- Node.js <= 0.50
# |   |   |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Node.js >  0.50
# |   |   |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- MySQL >  0.50
# |   |   |   |   |   |--- C <= 0.50
# |   |   |   |   |   |   |--- PHP <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- PHP >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- C >  0.50
# |   |   |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Kotlin >  0.50
# |   |   |   |   |--- TypeScript <= 0.50
# |   |   |   |   |   |--- .NET <= 0.50
# |   |   |   |   |   |   |--- Django <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Django >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- .NET >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- TypeScript >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- DynamoDB >  0.50
# |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |--- class: 0
# |   |--- Spring >  0.50
# |   |   |--- TypeScript <= 0.50
# |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |--- Firebase <= 0.50
# |   |   |   |   |   |--- VBA <= 0.50
# |   |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- VBA >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Firebase >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- TypeScript >  0.50
# |   |   |   |--- Ruby <= 0.50
# |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |   |--- Angular <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Angular >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Ruby >  0.50
# |   |   |   |   |--- class: 0
#
# -------------------------------
# 5503
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Developer, back-end
# |--- Spring <= 0.50
# |   |--- Redis <= 0.50
# |   |   |--- React.js <= 0.50
# |   |   |   |--- Firebase <= 0.50
# |   |   |   |   |--- R <= 0.50
# |   |   |   |   |   |--- Objective-C <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Objective-C >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- R >  0.50
# |   |   |   |   |   |--- MongoDB <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- MongoDB >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Firebase >  0.50
# |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |--- Go <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Go >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |--- Ruby on Rails <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Ruby on Rails >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- React.js >  0.50
# |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |--- Firebase <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Firebase >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |--- Ansible <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Ansible >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |--- SQL <= 0.50
# |   |   |   |   |   |--- Scala <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Scala >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- SQL >  0.50
# |   |   |   |   |   |--- C++ <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- C++ >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |--- Redis >  0.50
# |   |   |--- HTML/CSS <= 0.50
# |   |   |   |--- Keras <= 0.50
# |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |--- React Native <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- React Native >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Keras >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- HTML/CSS >  0.50
# |   |   |   |--- Python <= 0.50
# |   |   |   |   |--- Angular <= 0.50
# |   |   |   |   |   |--- Elasticsearch <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Elasticsearch >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Angular >  0.50
# |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Python >  0.50
# |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |--- VBA <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- VBA >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |--- class: 0
# |--- Spring >  0.50
# |   |--- HTML/CSS <= 0.50
# |   |   |--- Flutter <= 0.50
# |   |   |   |--- React.js <= 0.50
# |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |--- R <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- R >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- React.js >  0.50
# |   |   |   |   |--- SQL <= 0.50
# |   |   |   |   |   |--- Express <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Express >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- SQL >  0.50
# |   |   |   |   |   |--- Angular <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Angular >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- Flutter >  0.50
# |   |   |   |--- Dart <= 0.50
# |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Dart >  0.50
# |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |--- Swift <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Swift >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |--- class: 0
# |   |--- HTML/CSS >  0.50
# |   |   |--- Node.js <= 0.50
# |   |   |   |--- Java <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Java >  0.50
# |   |   |   |   |--- Redis <= 0.50
# |   |   |   |   |   |--- TypeScript <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TypeScript >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Redis >  0.50
# |   |   |   |   |   |--- IBM DB2 <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- IBM DB2 >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- Node.js >  0.50
# |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |--- SQL <= 0.50
# |   |   |   |   |   |--- Cassandra <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Cassandra >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- SQL >  0.50
# |   |   |   |   |   |--- MongoDB <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- MongoDB >  0.50
# |   |   |   |   |   |   |--- class: 1
#
# -------------------------------
# 1671
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Developer, desktop or enterprise applications
# |--- C# <= 0.50
# |   |--- C++ <= 0.50
# |   |   |--- Java <= 0.50
# |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |--- .NET <= 0.50
# |   |   |   |   |   |--- Rust <= 0.50
# |   |   |   |   |   |   |--- IBM DB2 <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- IBM DB2 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Rust >  0.50
# |   |   |   |   |   |   |--- Scala <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Scala >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- .NET >  0.50
# |   |   |   |   |   |--- Unity 3D <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Unity 3D >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |--- C <= 0.50
# |   |   |   |   |   |--- ASP.NET Core <= 0.50
# |   |   |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- ASP.NET Core >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- C >  0.50
# |   |   |   |   |   |--- Swift <= 0.50
# |   |   |   |   |   |   |--- Apache Spark <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Apache Spark >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Swift >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- Java >  0.50
# |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |--- Apache Spark <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Apache Spark >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |--- PHP <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PHP >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |--- .NET <= 0.50
# |   |   |   |   |   |   |--- C <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- C >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- .NET >  0.50
# |   |   |   |   |   |   |--- MariaDB <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- MariaDB >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Oracle >  0.50
# |   |   |   |   |--- Microsoft SQL Server <= 0.50
# |   |   |   |   |   |--- Pandas <= 0.50
# |   |   |   |   |   |   |--- Apache Spark <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Apache Spark >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Pandas >  0.50
# |   |   |   |   |   |   |--- Keras <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Keras >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Microsoft SQL Server >  0.50
# |   |   |   |   |   |--- Redis <= 0.50
# |   |   |   |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Redis >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- C++ >  0.50
# |   |   |--- Angular <= 0.50
# |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |--- TensorFlow <= 0.50
# |   |   |   |   |   |--- Laravel <= 0.50
# |   |   |   |   |   |   |--- Firebase <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Firebase >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Laravel >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- TensorFlow >  0.50
# |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- MySQL >  0.50
# |   |   |   |   |--- Objective-C <= 0.50
# |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |--- Spring <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Spring >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |--- Drupal <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Drupal >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Objective-C >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- Angular >  0.50
# |   |   |   |--- Rust <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Rust >  0.50
# |   |   |   |   |--- class: 1
# |--- C# >  0.50
# |   |--- JavaScript <= 0.50
# |   |   |--- DynamoDB <= 0.50
# |   |   |   |--- .NET <= 0.50
# |   |   |   |   |--- Elasticsearch <= 0.50
# |   |   |   |   |   |--- Ansible <= 0.50
# |   |   |   |   |   |   |--- Xamarin <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Xamarin >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Ansible >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Elasticsearch >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- .NET >  0.50
# |   |   |   |   |--- ASP.NET <= 0.50
# |   |   |   |   |   |--- Spring <= 0.50
# |   |   |   |   |   |   |--- Apache Spark <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Apache Spark >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Spring >  0.50
# |   |   |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- ASP.NET >  0.50
# |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- MySQL >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- DynamoDB >  0.50
# |   |   |   |--- class: 0
# |   |--- JavaScript >  0.50
# |   |   |--- VBA <= 0.50
# |   |   |   |--- C++ <= 0.50
# |   |   |   |   |--- Express <= 0.50
# |   |   |   |   |   |--- DynamoDB <= 0.50
# |   |   |   |   |   |   |--- MongoDB <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- MongoDB >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DynamoDB >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Express >  0.50
# |   |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- C++ >  0.50
# |   |   |   |   |--- Swift <= 0.50
# |   |   |   |   |   |--- Drupal <= 0.50
# |   |   |   |   |   |   |--- Haskell <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Haskell >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Drupal >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Swift >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- VBA >  0.50
# |   |   |   |--- class: 1
#
# -------------------------------
# 795
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Developer, embedded applications or devices
# |--- C <= 0.50
# |   |--- C++ <= 0.50
# |   |   |--- JavaScript <= 0.50
# |   |   |   |--- Rust <= 0.50
# |   |   |   |   |--- Torch/PyTorch <= 0.50
# |   |   |   |   |   |--- Drupal <= 0.50
# |   |   |   |   |   |   |--- Firebase <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Firebase >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Drupal >  0.50
# |   |   |   |   |   |   |--- Microsoft SQL Server <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Microsoft SQL Server >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Torch/PyTorch >  0.50
# |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Rust >  0.50
# |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- JavaScript >  0.50
# |   |   |   |--- React.js <= 0.50
# |   |   |   |   |--- Vue.js <= 0.50
# |   |   |   |   |   |--- SQL <= 0.50
# |   |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- SQL >  0.50
# |   |   |   |   |   |   |--- PHP <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PHP >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Vue.js >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- React.js >  0.50
# |   |   |   |   |--- R <= 0.50
# |   |   |   |   |   |--- Cordova <= 0.50
# |   |   |   |   |   |   |--- MongoDB <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- MongoDB >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Cordova >  0.50
# |   |   |   |   |   |   |--- PHP <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PHP >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- R >  0.50
# |   |   |   |   |   |--- class: 1
# |   |--- C++ >  0.50
# |   |   |--- HTML/CSS <= 0.50
# |   |   |   |--- Objective-C <= 0.50
# |   |   |   |   |--- Keras <= 0.50
# |   |   |   |   |   |--- Scala <= 0.50
# |   |   |   |   |   |   |--- Rust <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Rust >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Scala >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Keras >  0.50
# |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Objective-C >  0.50
# |   |   |   |   |--- Microsoft SQL Server <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Microsoft SQL Server >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- HTML/CSS >  0.50
# |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |--- Redis <= 0.50
# |   |   |   |   |   |--- Cordova <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Cordova >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Redis >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |--- Swift <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Swift >  0.50
# |   |   |   |   |   |--- class: 0
# |--- C >  0.50
# |   |--- Oracle <= 0.50
# |   |   |--- PHP <= 0.50
# |   |   |   |--- Laravel <= 0.50
# |   |   |   |   |--- Spring <= 0.50
# |   |   |   |   |   |--- Express <= 0.50
# |   |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Express >  0.50
# |   |   |   |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- MySQL >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Spring >  0.50
# |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |--- MongoDB <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- MongoDB >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Laravel >  0.50
# ...
# |   |   |   |   |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Unity 3D >  0.50
# |   |   |   |   |   |   |   |   |--- JavaScript <= 0.50
# |   |   |   |   |   |   |   |   |   |--- SQL <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- SQL >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- JavaScript >  0.50
# |   |   |   |   |   |   |   |   |   |--- PHP <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- PHP >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Cordova >  0.50
# |   |   |   |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |   |   |   |--- Django <= 0.50
# |   |   |   |   |   |   |   |   |   |--- jQuery <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- jQuery >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Django >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- React Native >  0.50
# |   |   |   |   |   |   |--- PostgreSQL <= 0.50
# |   |   |   |   |   |   |   |--- Elasticsearch <= 0.50
# |   |   |   |   |   |   |   |   |--- Redis <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Pandas <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Pandas >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Redis >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Elasticsearch >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PostgreSQL >  0.50
# |   |   |   |   |   |   |   |--- Spring <= 0.50
# |   |   |   |   |   |   |   |   |--- DynamoDB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- DynamoDB >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Spring >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Dart >  0.50
# |   |   |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |   |   |--- R <= 0.50
# |   |   |   |   |   |   |   |--- Spring <= 0.50
# |   |   |   |   |   |   |   |   |--- Flask <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Flask >  0.50
# |   |   |   |   |   |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Spring >  0.50
# |   |   |   |   |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- R >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Xamarin >  0.50
# |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |--- HTML/CSS <= 0.50
# |   |   |   |   |   |   |--- Angular.js <= 0.50
# |   |   |   |   |   |   |   |--- Oracle <= 0.50
# |   |   |   |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |   |   |   |--- .NET <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- .NET >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Oracle >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Angular.js >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- HTML/CSS >  0.50
# |   |   |   |   |   |   |--- Unity 3D <= 0.50
# |   |   |   |   |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- MySQL >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Unity 3D >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- Firebase >  0.50
# |   |   |   |--- Java <= 0.50
# |   |   |   |   |--- Flutter <= 0.50
# |   |   |   |   |   |--- React Native <= 0.50
# |   |   |   |   |   |   |--- ASP.NET <= 0.50
# |   |   |   |   |   |   |   |--- Objective-C <= 0.50
# |   |   |   |   |   |   |   |   |--- Angular <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Unity 3D <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Unity 3D >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Angular >  0.50
# |   |   |   |   |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Objective-C >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- ASP.NET >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- React Native >  0.50
# |   |   |   |   |   |   |--- Redis <= 0.50
# |   |   |   |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Redis >  0.50
# |   |   |   |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Flutter >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Java >  0.50
# |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |--- Xamarin <= 0.50
# |   |   |   |   |   |   |--- Express <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Express >  0.50
# |   |   |   |   |   |   |   |--- MySQL <= 0.50
# |   |   |   |   |   |   |   |   |--- C++ <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- C++ >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- MySQL >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Xamarin >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |--- MongoDB <= 0.50
# |   |   |   |   |   |   |   |--- DynamoDB <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- DynamoDB >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- MongoDB >  0.50
# |   |   |   |   |   |   |   |--- Redis <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Redis >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- Kotlin >  0.50
# |   |   |--- Elasticsearch <= 0.50
# |   |   |   |--- Spring <= 0.50
# |   |   |   |   |--- Apache Spark <= 0.50
# |   |   |   |   |   |--- Vue.js <= 0.50
# |   |   |   |   |   |   |--- Haskell <= 0.50
# |   |   |   |   |   |   |   |--- Pandas <= 0.50
# |   |   |   |   |   |   |   |   |--- Ruby on Rails <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Scala <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Scala >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Ruby on Rails >  0.50
# |   |   |   |   |   |   |   |   |   |--- Ruby <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Ruby >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Pandas >  0.50
# |   |   |   |   |   |   |   |   |--- C# <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- C# >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Haskell >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Vue.js >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Apache Spark >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Spring >  0.50
# |   |   |   |   |--- Go <= 0.50
# |   |   |   |   |   |--- React.js <= 0.50
# |   |   |   |   |   |   |--- Ansible <= 0.50
# |   |   |   |   |   |   |   |--- jQuery <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- jQuery >  0.50
# |   |   |   |   |   |   |   |   |--- SQL <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- SQL >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Ansible >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- React.js >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Go >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- Elasticsearch >  0.50
# |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |--- React Native <= 0.50
# |   |   |   |   |   |--- jQuery <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- jQuery >  0.50
# |   |   |   |   |   |   |--- Go <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Go >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- React Native >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- SQLite >  0.50
# |   |   |   |   |--- class: 1
# |--- Swift >  0.50
# |   |--- Scala <= 0.50
# |   |   |--- Teraform <= 0.50
# |   |   |   |--- ASP.NET <= 0.50
# |   |   |   |   |--- Python <= 0.50
# |   |   |   |   |   |--- Keras <= 0.50
# |   |   |   |   |   |   |--- MariaDB <= 0.50
# |   |   |   |   |   |   |   |--- Go <= 0.50
# |   |   |   |   |   |   |   |   |--- Objective-C <= 0.50
# |   |   |   |   |   |   |   |   |   |--- C++ <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- C++ >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Objective-C >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Go >  0.50
# |   |   |   |   |   |   |   |   |--- Ruby <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Ruby >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- MariaDB >  0.50
# |   |   |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Keras >  0.50
# |   |   |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Python >  0.50
# |   |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |   |--- Rust <= 0.50
# |   |   |   |   |   |   |   |--- Bash/Shell/PowerShell <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Bash/Shell/PowerShell >  0.50
# |   |   |   |   |   |   |   |   |--- Node.js <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Assembly <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Assembly >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Node.js >  0.50
# |   |   |   |   |   |   |   |   |   |--- TypeScript <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TypeScript >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Rust >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |   |--- Kotlin <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Kotlin >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- ASP.NET >  0.50
# |   |   |   |   |--- SQLite <= 0.50
# |   |   |   |   |   |--- .NET Core <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- .NET Core >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- SQLite >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- Teraform >  0.50
# |   |   |   |--- Ansible <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Ansible >  0.50
# |   |   |   |   |--- class: 1
# |   |--- Scala >  0.50
# |   |   |--- SQLite <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- SQLite >  0.50
# |   |   |   |--- class: 1
#
# -------------------------------
# 483
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Engineer, data
# |--- Python <= 0.50
# |   |--- Apache Spark <= 0.50
# |   |   |--- class: 0
# |   |--- Apache Spark >  0.50
# |   |   |--- class: 1
# |--- Python >  0.50
# |   |--- Apache Spark <= 0.50
# |   |   |--- class: 1
# |   |--- Apache Spark >  0.50
# |   |   |--- class: 1
#
# -------------------------------
# 292
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# Scientist
# |--- Python <= 0.50
# |   |--- R <= 0.50
# |   |   |--- C <= 0.50
# |   |   |   |--- Assembly <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Assembly >  0.50
# |   |   |   |   |--- class: 1
# |   |   |--- C >  0.50
# |   |   |   |--- SQL <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- SQL >  0.50
# |   |   |   |   |--- class: 0
# |   |--- R >  0.50
# |   |   |--- Oracle <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- Oracle >  0.50
# |   |   |   |--- class: 0
# |--- Python >  0.50
# |   |--- PostgreSQL <= 0.50
# |   |   |--- Vue.js <= 0.50
# |   |   |   |--- DynamoDB <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- DynamoDB >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- Vue.js >  0.50
# |   |   |   |--- class: 0
# |   |--- PostgreSQL >  0.50
# |   |   |--- R <= 0.50
# |   |   |   |--- Pandas <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Pandas >  0.50
# |   |   |   |   |--- class: 1
# |   |   |--- R >  0.50
# |   |   |   |--- Node.js <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- Node.js >  0.50
# |   |   |   |   |--- class: 0
#
# -------------------------------
# 440
# C:\Users\oem\anaconda3\anacond_3\lib\site-packages\pandas\core\generic.py:3887: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# **********************
# System administrator
# |--- Bash/Shell/PowerShell <= 0.50
# |   |--- HTML/CSS <= 0.50
# |   |   |--- Go <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- Go >  0.50
# |   |   |   |--- class: 1
# |   |--- HTML/CSS >  0.50
# |   |   |--- React.js <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- React.js >  0.50
# |   |   |   |--- class: 0
# |--- Bash/Shell/PowerShell >  0.50
# |   |--- Java <= 0.50
# |   |   |--- JavaScript <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- JavaScript >  0.50
# |   |   |   |--- class: 1
# |   |--- Java >  0.50
# |   |   |--- Go <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- Go >  0.50
# |   |   |   |--- class: 1
#
# -------------------------------

# %%
os.makedirs(os.path.dirname(EXPORT_PATH), exist_ok=  True)

with open (EXPORT_PATH,'wb') as handel:
    
    pickle.dump(models,handel)

# %% [raw]
# models.keys()

# %%
models.keys()
# Out:
# dict_keys(['Academic researcher', 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Engineer, data', 'Scientist', 'System administrator'])
